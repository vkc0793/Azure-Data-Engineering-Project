# %%
import pyarrow.csv as pv
import pyarrow.parquet as pq

# Read the CSV file
csv_file = "2025-vinlist02 - deletion.csv"
table = pv.read_csv(csv_file)

# Write to Parquet
pq.write_table(table, "data.parquet")
